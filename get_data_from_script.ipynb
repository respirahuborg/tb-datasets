# %%
import os
import synapseclient
from tqdm import tqdm

def get_table_info(synID):
    """
    Get table information from file view 

    Args:
         synID: File view Synapse ID
    """
    token = os.environ.get('SYNAPSE_AUTH_TOKEN')
    if not token:
        raise ValueError("Set env variable: export SYNAPSE_AUTH_TOKEN=your_token_here")

    syn = synapseclient.Synapse()
    syn.login(authToken=token)

    query_results = syn.tableQuery("SELECT * FROM " + synID)
    syn_df = query_results.asDataFrame()
    
    return syn, syn_df

def download_data(synID, dest_folder):
    """
    Downloading training dataset

    Args:
         synID: File view Synapse ID
         dest_folder: Directory path to download training dataset
    """
    syn, syn_df = get_table_info(synID)
    for index, row in tqdm(syn_df.iterrows()):
        syn.get(row['id'], downloadLocation=dest_folder)
    print('Downloaded all the files successfully...')

# download_data('syn41833327', 'data/solicited/')    # Download solicited coughs only
# download_data('syn41833579', 'data/longitudinal/') # Download longitudinal coughs only
# download_data('syn41833579', 'data/metadata/') # Download longitudinal coughs only

# %%
syn, df = get_table_info('syn41833579')
print(df.columns.tolist())
print(df.shape)
print(df.head(3))
# Out:
# Welcome, CupSurg!
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/847951954.py:19: DeprecationWarning: Call to deprecated method tableQuery. (To be removed in 5.0.0. Use the `query` functions from `synapseclient.models.Table` instead. Check the docstring for the replacement function example.) -- Deprecated since version 4.9.0.
#   query_results = syn.tableQuery("SELECT * FROM " + synID)
#
# Create CSV FileHandle: 100%|██████████| 1.43M/1.43M [00:14<00:00, 99.9kit/s]
# Downloading files:  97%|█████████▋| 314M/322M [02:20<00:03, 2.23MB/s, syn41833579]
# [syn41833579]: Downloaded to /Users/aida/.synapseCache/422/169333422/SYNAPSE_TABLE_QUERY_169333422.csv
# Downloading files: 100%|██████████| 322M/322M [02:22<00:00, 2.27MB/s, syn41833579]
# ['id', 'name', 'createdOn', 'createdBy', 'etag', 'type', 'currentVersion', 'parentId', 'benefactorId', 'projectId', 'modifiedOn', 'modifiedBy', 'dataFileHandleId', 'dataFileSizeBytes', 'dataFileMD5Hex', 'dataFileConcreteType', 'dataFileBucket', 'dataFileKey']
# (714922, 18)
#                                                           id  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  syn40392638
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  syn40392639
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  syn40392640
#
#                                                                           name  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  1620627631190-recording-1.wav
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  1620627635670-recording-1.wav
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  1620633332149-recording-1.wav
#
#                                                      createdOn  createdBy  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  1666064958022    3428786
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  1666064958581    3428786
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  1666064959179    3428786
#
#                                                                                  etag  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  f03e0be0-5ff7-4159-9c5e-61ea4610189d
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  468a2154-74bf-442d-8c87-4fa8f47648ef
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  be3319bb-afde-4c30-b438-f028cb5b17c3
#
#                                                  type  currentVersion  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  file               1
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  file               1
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  file               1
#
#                                                     parentId benefactorId  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  syn40390832  syn38943763
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  syn40390832  syn38943763
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  syn40390832  syn38943763
#
#                                                    projectId     modifiedOn  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  syn31472953  1666064958178
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  syn31472953  1666064958752
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  syn31472953  1666064959342
#
#                                                  modifiedBy  dataFileHandleId  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d     3428786          91959487
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef     3428786          91959488
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3     3428786          91959494
#
#                                                  dataFileSizeBytes  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d              44178
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef              44178
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3              44178
#
#                                                                    dataFileMD5Hex  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  4901e79e6025ddf7359800edf78f9374
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  46b5e9db39fa1299a8a65ad90b7d6b46
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  6ed4c1daca509aece728a497ad906547
#
#                                                                              dataFileConcreteType  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  org.sagebionetworks.repo.model.file.S3FileHandle
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  org.sagebionetworks.repo.model.file.S3FileHandle
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  org.sagebionetworks.repo.model.file.S3FileHandle
#
#                                                         dataFileBucket  \
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  proddata.sagebase.org
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  proddata.sagebase.org
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  proddata.sagebase.org
#
#                                                                                        dataFileKey
# 40392638_1_f03e0be0-5ff7-4159-9c5e-61ea4610189d  3428786/62ddba6c-0a41-49aa-aa33-9400789091ef/1...
# 40392639_1_468a2154-74bf-442d-8c87-4fa8f47648ef  3428786/57b88bcf-e941-4e3a-8a88-8cf8a4e9b2b6/1...
# 40392640_1_be3319bb-afde-4c30-b438-f028cb5b17c3  3428786/4c0dfcef-2781-4c63-b1dc-b976b846fe54/1...

# %%
syn, df = get_table_info('syn41833327')  # solicited file view
print("Parent IDs:")
print(df['parentId'].unique())
# Out:
# Welcome, CupSurg!
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/847951954.py:19: DeprecationWarning: Call to deprecated method tableQuery. (To be removed in 5.0.0. Use the `query` functions from `synapseclient.models.Table` instead. Check the docstring for the replacement function example.) -- Deprecated since version 4.9.0.
#   query_results = syn.tableQuery("SELECT * FROM " + synID)
#
# Create CSV FileHandle: 100%|██████████| 19.5k/19.5k [00:01<00:00, 12.9kit/s]
# Downloading files:  95%|█████████▌| 4.19M/4.40M [00:03<00:00, 1.29MB/s, syn41833327]
# [syn41833327]: Downloaded to /Users/aida/.synapseCache/453/169333453/SYNAPSE_TABLE_QUERY_169333453.csv
# Downloading files: 100%|██████████| 4.40M/4.40M [00:03<00:00, 1.26MB/s, syn41833327]
# Parent IDs:
# ['syn40358494']

# %%
children = list(syn.getChildren('syn31472953'))
for c in children:
    print(f"{c['name']:>40s}  {c['id']}  {c['type']}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/1138186844.py:1: DeprecationWarning: Call to deprecated method getChildren. (To be removed in 5.0.0. Use the new dataclass models `from synapseclient.models import Project, Folder` with their `sync_from_synapse` method for most use cases, or the `synapseclient.api.get_children` function for direct API access with sorting and filtering.) -- Deprecated since version 4.9.0.
#   children = list(syn.getChildren('syn31472953'))
#                       CODA Challenge SC1  syn51366229  org.sagebionetworks.repo.model.table.TableEntity
# CODA Challenge SC1 Final Results (Original)  syn51196305  org.sagebionetworks.repo.model.table.TableEntity
#         CODA Challenge SC2 Final Results  syn51196438  org.sagebionetworks.repo.model.table.TableEntity
#                                     Data  syn38943763  org.sagebionetworks.repo.model.Folder
#                             General Info  syn46738742  org.sagebionetworks.repo.model.Folder
#                  Leaderboard SC1 Ranking  syn50970432  org.sagebionetworks.repo.model.table.TableEntity
#                  Leaderboard SC2 Ranking  syn49581544  org.sagebionetworks.repo.model.table.TableEntity
#                                     Logs  syn31476674  org.sagebionetworks.repo.model.Folder
#                  Longitudinal Train View  syn41833579  org.sagebionetworks.repo.model.table.EntityView
#                                 New-Logs  syn64951434  org.sagebionetworks.repo.model.Folder
#                     Solicited Train View  syn41833327  org.sagebionetworks.repo.model.table.EntityView

# %%
children = list(syn.getChildren('syn38943763'))
for c in children:
    print(f"{c['name']:>40s}  {c['id']}  {c['type']}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/990335200.py:1: DeprecationWarning: Call to deprecated method getChildren. (To be removed in 5.0.0. Use the new dataclass models `from synapseclient.models import Project, Folder` with their `sync_from_synapse` method for most use cases, or the `synapseclient.api.get_children` function for direct API access with sorting and filtering.) -- Deprecated since version 4.9.0.
#   children = list(syn.getChildren('syn38943763'))
#                                    Train  syn39711065  org.sagebionetworks.repo.model.Folder

# %%
syn.get('participant_data.csv_syn31472953', downloadLocation='data/metadata/')
syn.get('sound_to_participant.csv_syn31472953', downloadLocation='data/metadata/')
syn.get('data_dictionary.csv_syn31472953', downloadLocation='data/metadata/')
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/1288483399.py:1: DeprecationWarning: Call to deprecated method get. (To be removed in 5.0.0. Use `from synapseclient.operations import get` instead.) -- Deprecated since version 4.11.0.
#   syn.get('participant_data.csv_syn31472953', downloadLocation='data/metadata/')
# ---------------------------------------------------------------------------
# SynapseFileNotFoundError                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 syn.get('participant_data.csv_syn31472953', downloadLocation='data/metadata/')
#       2 syn.get('sound_to_participant.csv_syn31472953', downloadLocation='data/metadata/')
#       3 syn.get('data_dictionary.csv_syn31472953', downloadLocation='data/metadata/')
#
# File ~/code/development/tb-datasets/.venv/lib/python3.10/site-packages/deprecated/classic.py:199, in ClassicAdapter.__call__.<locals>.wrapper_function(wrapped_, instance_, args_, kwargs_)
#     197 else:
#     198     warnings.warn(msg, category=self.category, stacklevel=stacklevel)
# --> 199 return wrapped_(*args_, **kwargs_)
#
# File ~/code/development/tb-datasets/.venv/lib/python3.10/site-packages/synapseclient/client.py:1764, in Synapse.get(self, entity, **kwargs)
#    1713 @deprecated(
#    1714     version="4.11.0",
#    1715     reason="To be removed in 5.0.0. "
#    1716     "Use `from synapseclient.operations import get` instead.",
#    1717 )
#    1718 def get(self, entity, **kwargs):
#    1719     """
#    1720     Gets a Synapse entity from the repository service.
#    1721
#    (...)
#    1762             print(syn.getProvenance(entity))
#    1763     """
# -> 1764     return wrap_async_to_sync(self.get_async(entity, **kwargs))
#
# File ~/code/development/tb-datasets/.venv/lib/python3.10/site-packages/synapseclient/core/async_utils.py:99, in wrap_async_to_sync(coroutine)
#      97 elif loop:
#      98     nest_asyncio.apply(loop=loop)
# ---> 99     return loop.run_until_complete(coroutine)
#     100 else:
#     101     return asyncio.run(coroutine)
#
# File ~/code/development/tb-datasets/.venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/code/development/tb-datasets/.venv/lib/python3.10/site-packages/synapseclient/client.py:1822, in Synapse.get_async(self, entity, **kwargs)
#    1819     kwargs["path"] = entity
#    1821 elif isinstance(entity, str) and not utils.is_synapse_id_str(entity):
# -> 1822     raise SynapseFileNotFoundError(
#    1823         (
#    1824             "The parameter %s is neither a local file path "
#    1825             " or a valid entity id" % entity
#    1826         )
#    1827     )
#    1828 # have not been saved entities
#    1829 elif isinstance(entity, Entity) and not entity.get("id"):
#
# SynapseFileNotFoundError: The parameter participant_data.csv_syn31472953 is neither a local file path  or a valid entity id

# %%
children = list(syn.getChildren('syn38943763'))
for c in children:
    print(f"{c['name']:>40s}  {c['id']}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/1351958193.py:1: DeprecationWarning: Call to deprecated method getChildren. (To be removed in 5.0.0. Use the new dataclass models `from synapseclient.models import Project, Folder` with their `sync_from_synapse` method for most use cases, or the `synapseclient.api.get_children` function for direct API access with sorting and filtering.) -- Deprecated since version 4.9.0.
#   children = list(syn.getChildren('syn38943763'))
#                                    Train  syn39711065

# %%
children = list(syn.getChildren('syn39711065'))
for c in children:
    print(f"{c['name']:>40s}  {c['id']}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/3922448531.py:1: DeprecationWarning: Call to deprecated method getChildren. (To be removed in 5.0.0. Use the new dataclass models `from synapseclient.models import Project, Folder` with their `sync_from_synapse` method for most use cases, or the `synapseclient.api.get_children` function for direct API access with sorting and filtering.) -- Deprecated since version 4.9.0.
#   children = list(syn.getChildren('syn39711065'))
#                                meta_data  syn39711415
#                                 raw_data  syn39711400

# %%
children = list(syn.getChildren('syn39711415'))
for c in children:
    print(f"{c['name']:>40s}  {c['id']}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/2413178872.py:1: DeprecationWarning: Call to deprecated method getChildren. (To be removed in 5.0.0. Use the new dataclass models `from synapseclient.models import Project, Folder` with their `sync_from_synapse` method for most use cases, or the `synapseclient.api.get_children` function for direct API access with sorting and filtering.) -- Deprecated since version 4.9.0.
#   children = list(syn.getChildren('syn39711415'))
#   CODA TB Challenge data dictionary.xlsx  syn41743692
#                                 Clinical  syn53710097
#                           Cough Metadata  syn53710098

# %%
syn.get('syn41743692', downloadLocation='data/metadata/')  # data dictionary
syn.get('syn53710097', downloadLocation='data/metadata/')   # Clinical
syn.get('syn53710098', downloadLocation='data/metadata/')   # Cough Metadata
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/2469370713.py:1: DeprecationWarning: Call to deprecated method get. (To be removed in 5.0.0. Use `from synapseclient.operations import get` instead.) -- Deprecated since version 4.11.0.
#   syn.get('syn41743692', downloadLocation='data/metadata/')  # data dictionary
#
# Downloading files: 100%|██████████| 19.7k/19.7k [00:00<00:00, 31.0kB/s, syn41743692]
# [syn41743692]: Downloaded to /Users/aida/code/development/tb-datasets/data/metadata/CODA TB Challenge data dictionary_update.xlsx
# Downloading files: 100%|██████████| 19.7k/19.7k [00:00<00:00, 30.9kB/s, syn41743692]
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/2469370713.py:2: DeprecationWarning: Call to deprecated method get. (To be removed in 5.0.0. Use `from synapseclient.operations import get` instead.) -- Deprecated since version 4.11.0.
#   syn.get('syn53710097', downloadLocation='data/metadata/')   # Clinical
#
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/2469370713.py:3: DeprecationWarning: Call to deprecated method get. (To be removed in 5.0.0. Use `from synapseclient.operations import get` instead.) -- Deprecated since version 4.11.0.
#   syn.get('syn53710098', downloadLocation='data/metadata/')   # Cough Metadata
# Folder(etag='cb23fa81-57a5-4284-9cbc-d0de0bdc77ba', id='syn53710098', modifiedBy='273959', concreteType='org.sagebionetworks.repo.model.Folder', createdBy='273959', modifiedOn='2024-02-29T18:02:27.483Z', createdOn='2024-02-29T18:02:27.483Z', name='Cough Metadata', parentId='syn39711415')

# %%
for sid, name in [('syn53710097', 'Clinical'), ('syn53710098', 'Cough Metadata')]:
    children = list(syn.getChildren(sid))
    print(f"\n=== {name} ===")
    for c in children:
        print(f"  {c['name']:>50s}  {c['id']}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/2273743574.py:2: DeprecationWarning: Call to deprecated method getChildren. (To be removed in 5.0.0. Use the new dataclass models `from synapseclient.models import Project, Folder` with their `sync_from_synapse` method for most use cases, or the `synapseclient.api.get_children` function for direct API access with sorting and filtering.) -- Deprecated since version 4.9.0.
#   children = list(syn.getChildren(sid))
# === Clinical ===
#                       CODA_TB_Clinical_Meta_Info.csv  syn41604915
#               CODA_TB_additional_variables_train.csv  syn52357041
#
# === Cough Metadata ===
#                    CODA_TB_Longitudnal_Meta_Info.csv  syn41604935
#                      CODA_TB_Solicited_Meta_Info.csv  syn41604939

# %%
for sid in ['syn41604915', 'syn52357041', 'syn41604935', 'syn41604939']:
    syn.get(sid, downloadLocation='data/metadata/')
    print(f"Downloaded {sid}")
# Out:
# [WARNING] /var/folders/gm/gdhdkspj21v4nnjj52c3g8t00000gn/T/ipykernel_30507/1840592698.py:2: DeprecationWarning: Call to deprecated method get. (To be removed in 5.0.0. Use `from synapseclient.operations import get` instead.) -- Deprecated since version 4.11.0.
#   syn.get(sid, downloadLocation='data/metadata/')
#
# Downloading files: 100%|██████████| 79.8k/79.8k [00:00<00:00, 98.4kB/s, syn41604915]
# [syn41604915]: Downloaded to /Users/aida/code/development/tb-datasets/data/metadata/CODA_TB_Clinical_Meta_Info.csv
# Downloading files: 100%|██████████| 79.8k/79.8k [00:00<00:00, 97.9kB/s, syn41604915]
# Downloaded syn41604915
# Downloading files: 100%|██████████| 74.6k/74.6k [00:00<00:00, 96.8kB/s, syn52357041]
# [syn52357041]: Downloaded to /Users/aida/code/development/tb-datasets/data/metadata/CODA_TB_additional_variables_train.csv
# Downloading files: 100%|██████████| 74.6k/74.6k [00:00<00:00, 96.2kB/s, syn52357041]
# Downloaded syn52357041
# Downloading files: 100%|██████████| 44.2M/44.2M [00:20<00:00, 2.16MB/s, syn41604935]
# [syn41604935]: Downloaded to /Users/aida/code/development/tb-datasets/data/metadata/CODA_TB_Longitudnal_Meta_Info.csv
# Downloading files: 100%|██████████| 44.2M/44.2M [00:20<00:00, 2.16MB/s, syn41604935]
# Downloaded syn41604935
# Downloading files: 100%|██████████| 604k/604k [00:00<00:00, 612kB/s, syn41604939]
# [syn41604939]: Downloaded to /Users/aida/code/development/tb-datasets/data/metadata/CODA_TB_Solicited_Meta_Info.csv
# Downloading files: 100%|██████████| 604k/604k [00:00<00:00, 611kB/s, syn41604939]
# Downloaded syn41604939
